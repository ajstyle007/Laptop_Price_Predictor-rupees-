# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz  8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price
# 0  1.37kg  71378.6832

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2601051860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram'] = df['Ram'].str.replace('GB','')
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2601051860.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu Ram               Memory  \
# 0  Intel Core i5 2.3GHz   8            128GB SSD
# 1  Intel Core i5 1.8GHz   8  128GB Flash Storage
#
#                             Gpu  OpSys Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37  71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34  47895.5232

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\369679562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram'] = df['Ram'].astype('int32')
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\369679562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 109.5+ KB

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(df["Price"])
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\941010651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# as we can see above that maximum laptops have low price and few laptops have high price which is very obvious.

# %%
sns.barplot(df["Company"].value_counts())
plt.xticks(rotation=45)
plt.show()

# %%
# from above we can see that most seelings laptop companies are Dell, lenovo, HP, Asus and acer.

# %%
df["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              706
# Gaming                205
# Ultrabook             194
# 2 in 1 Convertible    117
# Workstation            29
# Netbook                23
# Name: count, dtype: int64

# %%
fig = sns.barplot(df["TypeName"].value_counts(), color="green")
plt.xticks(rotation=45)
plt.show()

# %%
# from above we can see that notebook type laptops are most selling, then we have gaming and ultrabook.

# %%
df["Inches"].value_counts()
# Out:
# Inches
# 15.6    646
# 14.0    193
# 17.3    164
# 13.3    160
# 12.5     39
# 11.6     31
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
sns.barplot(df["Inches"].value_counts(), orient='h', color="red")
plt.xticks(rotation=45)
plt.show()

# %%
# from above we can see that we have maximum number of laptops with screen size 15.6 inches

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price
# 0    1.37  71378.6832

# %%
df["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                505
# 1366x768                                         262
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
# from above column we can extract the if the laptop has touchscreen or not and if the laptop has IPS panel or not and screen resolution

# %%
df["Touchscreen"] = df["ScreenResolution"].apply(lambda x: 1 if "Touchscreen" in x else 0)
df["Touchscreen"]
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1400895641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Touchscreen"] = df["ScreenResolution"].apply(lambda x: 1 if "Touchscreen" in x else 0)
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1269    0
# 1270    1
# 1271    1
# 1272    0
# 1273    0
# Name: Touchscreen, Length: 1274, dtype: int64

# %%
df.sample(2)
# Out:
#     Company  TypeName  Inches             ScreenResolution  \
# 439    Asus  Notebook    15.6            Full HD 1920x1080
# 785     MSI    Gaming    14.0  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 439   Intel Core i5 7200U 2.5GHz    4             256GB SSD
# 785  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight      Price  Touchscreen
# 439    Intel HD Graphics 620       Linux     2.0   29783.52            0
# 785  Nvidia GeForce GTX 1060  Windows 10     1.6  100752.48            0

# %%
plt.figure(figsize=(5,3))
sns.barplot(df["Touchscreen"].value_counts(), color="red")
plt.show()

# %%
# laptop with touchscreen are less selling because i think the price is high

# %%
df["IPS"] = df["ScreenResolution"].apply(lambda x: 1 if "IPS" in x else 0)
df["IPS"]
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\3131026997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IPS"] = df["ScreenResolution"].apply(lambda x: 1 if "IPS" in x else 0)
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 1269    0
# 1270    1
# 1271    1
# 1272    0
# 1273    0
# Name: IPS, Length: 1274, dtype: int64

# %%
df.sample(3)
# Out:
#       Company   TypeName  Inches                 ScreenResolution  \
# 491   Toshiba  Ultrabook    13.3  Full HD / Touchscreen 1920x1080
# 1245     Asus     Gaming    15.6      IPS Panel Full HD 1920x1080
# 475      Dell   Notebook    14.0                         1366x768
#
#                               Cpu  Ram                Memory  \
# 491    Intel Core i7 7500U 2.7GHz   32             512GB SSD
# 1245  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 475    Intel Core i3 6100U 2.3GHz    8             128GB SSD
#
#                              Gpu       OpSys  Weight      Price  Touchscreen  \
# 491        Intel HD Graphics 620  Windows 10    1.05  149130.72            1
# 1245  Nvidia GeForce GTX 1050 Ti  Windows 10    2.50   85248.00            0
# 475        Intel HD Graphics 520  Windows 10    1.79   39427.20            0
#
#       IPS
# 491     0
# 1245    1
# 475     0

# %%
plt.figure(figsize=(5,3))
sns.barplot(df["IPS"].value_counts(), color="violet")
# Out:
# <Axes: xlabel='IPS', ylabel='count'>

# %%
# now we will extract the screen resolution from that column

# %%
df["ScreenResolution"]
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1269                                      1366x768
# 1270     IPS Panel Full HD / Touchscreen 1920x1080
# 1271    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                      1366x768
# 1273                                      1366x768
# Name: ScreenResolution, Length: 1274, dtype: object

# %%
new_df = df["ScreenResolution"].str.split("x", expand=True)
new_df
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1269                                   1366   768
# 1270   IPS Panel Full HD / Touchscreen 1920  1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1272                                   1366   768
# 1273                                   1366   768
#
# [1274 rows x 2 columns]

# %%
df["X_res"] = new_df[0]
df["Y_res"] = new_df[1]
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\3613930623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["X_res"] = new_df[0]
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\3613930623.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Y_res"] = new_df[1]

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#                            X_res Y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900

# %%
df["X_res"].str.replace(",", " ").str.findall(r'(\d+\.?\d+)').apply(lambda x : x[0])
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1269    1366
# 1270    1920
# 1271    3200
# 1272    1366
# 1273    1366
# Name: X_res, Length: 1274, dtype: object

# %%
df["X_res"].str.split(" ").apply(lambda x:x[-1])
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1269    1366
# 1270    1920
# 1271    3200
# 1272    1366
# 1273    1366
# Name: X_res, Length: 1274, dtype: object

# %%
df["X_res"] = df["X_res"].str.replace(",", " ").str.findall(r'(\d+\.?\d+)').apply(lambda x : x[0])
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1834791439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["X_res"] = df["X_res"].str.replace(",", " ").str.findall(r'(\d+\.?\d+)').apply(lambda x : x[0])

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  IPS               1274 non-null   int64
#  13  X_res             1274 non-null   object
#  14  Y_res             1274 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df["X_res"] = df["X_res"].astype("int64")
df["Y_res"] = df["Y_res"].astype("int64")
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2753041800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["X_res"] = df["X_res"].astype("int64")
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2753041800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Y_res"] = df["Y_res"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  IPS               1274 non-null   int64
#  13  X_res             1274 non-null   int64
#  14  Y_res             1274 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %% [markdown]
# ## Bivariate Analysis

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS  X_res  Y_res
# 0    1.37  71378.6832            0    1   2560   1600

# %%
sns.barplot(data = df, x = df["Company"], y= df["Price"], hue = df["Company"], palette="hsv")
plt.xticks(rotation=45)
plt.show()

# %%
#from above we can conclude that laptops of companies Razor, MSI, LG have higher prices while HP, Asus, Dell, and lenovo have medium prices

# %%
sns.barplot(data = df, x = df["TypeName"], y = df["Price"], hue = df["TypeName"])
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(df, y = df["Inches"], x = df["Price"])
plt.xticks(rotation = 45)
plt.show()

# %%
# from above we can as the screen size increases the price of the laptops also increases

# %%
# from above we can see the we have maximum number of laptops with intel CPU's then AMD

# %%
df['Cpu'].value_counts().head(20)
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              190
# Intel Core i7 7700HQ 2.8GHz             146
# Intel Core i7 7500U 2.7GHz              132
# Intel Core i7 8550U 1.8GHz               73
# Intel Core i5 8250U 1.6GHz               72
# Intel Core i5 6200U 2.3GHz               68
# Intel Core i3 6006U 2GHz                 64
# Intel Core i7 6500U 2.5GHz               41
# Intel Core i7 6700HQ 2.6GHz              41
# Intel Core i3 7100U 2.4GHz               35
# Intel Core i5 7300HQ 2.5GHz              33
# Intel Celeron Dual Core N3350 1.1GHz     30
# Intel Celeron Dual Core N3060 1.6GHz     24
# Intel Core i7 6600U 2.6GHz               18
# Intel Core i3 6006U 2.0GHz               16
# Intel Core i5 7300U 2.6GHz               14
# Intel Pentium Quad Core N4200 1.1GHz     14
# Intel Core i7 7600U 2.8GHz               13
# Intel Pentium Quad Core N3710 1.6GHz     11
# Intel Core i5 6300U 2.4GHz               11
# Name: count, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1977272338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#    X_res  Y_res       Cpu Name
# 0   2560   1600  Intel Core i5
# 1   1440    900  Intel Core i5

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# IPS            0.250358
# X_res          0.552074
# Y_res          0.548111
# Name: Price, dtype: float64

# %%
# from above we can see that the correlation of different columns with Price column
# Ram has highest corr
# and inches has lowest
# by using the Inches, X_res, Y_res columns we can create a new column called PPi means Pixels per inch

# %%
# Pixels per inch
# A measurement of the number of pixels in each inch of a digital image or video display.
# Formula 
# ppi = ((X_res)^2 + (Y_res)^2)^1/2 / Inches

# %%
df["ppi"] = ((df["X_res"])**2 + (df["Y_res"])**2 )**0.5 / df["Inches"]
df["ppi"]
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2117769388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ppi"] = ((df["X_res"])**2 + (df["Y_res"])**2 )**0.5 / df["Inches"]
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1269    100.454670
# 1270    157.350512
# 1271    276.053530
# 1272    111.935204
# 1273    100.454670
# Name: ppi, Length: 1274, dtype: float64

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# IPS            0.250358
# X_res          0.552074
# Y_res          0.548111
# ppi            0.469539
# Name: Price, dtype: float64

# %%
# from above we can see that ppi has come correlation with price

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  IPS               1274 non-null   int64
#  13  X_res             1274 non-null   int64
#  14  Y_res             1274 non-null   int64
#  15  Cpu Name          1274 non-null   object
# ...

# %%
def Processor(text):
    if text == "Intel Core i5" or text == "Intel Core i3" or text == "Intel Core i7" or text == "Intel Core i9":
        return text
    else:
        if text.split()[0] == "intel":
            return "Other Intel Processor"
        else:
            return "AMD Processor"

# %%
df["Cpu Name"].apply(Processor).value_counts()
# Out:
# Cpu Name
# Intel Core i7    515
# Intel Core i5    423
# AMD Processor    202
# Intel Core i3    134
# Name: count, dtype: int64

# %%
df["CPU Brand"] = df["Cpu Name"].apply(Processor)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1673850036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CPU Brand"] = df["Cpu Name"].apply(Processor)

# %%
df.sample(3)
# Out:
#     Company   TypeName  Inches             ScreenResolution  \
# 926  Lenovo  Ultrabook    12.5  IPS Panel Full HD 1920x1080
# 242    Asus   Notebook    17.3            Full HD 1920x1080
# 165     MSI     Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 926   Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 242   Intel Core i7 7500U 2.7GHz    8  128GB SSD +  1TB HDD
# 165  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight     Price  Touchscreen  IPS  \
# 926    Intel HD Graphics 620  Windows 10    1.36  87912.00            0    1
# 242  Nvidia GeForce GTX 950M       No OS    2.69  47365.92            0    0
# 165  Nvidia GeForce GTX 1060  Windows 10    2.40  95850.72            0    1
#
#      X_res  Y_res       Cpu Name         ppi      CPU Brand
# 926   1920   1080  Intel Core i7  176.232574  Intel Core i7
# ...

# %%
sns.barplot(df["CPU Brand"].value_counts())
plt.show()

# %%
sns.barplot(data = df, x = df["CPU Brand"], y = df["Price"], hue = df["CPU Brand"])
plt.xticks(rotation=45)
plt.show()

# %%
# from above we can see that the prices of i7 and i5 are higher than i3 and AMD processor laptops

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS  X_res  Y_res       Cpu Name  \
# 0    1.37  71378.6832            0    1   2560   1600  Intel Core i5
#
#           ppi      CPU Brand
# 0  226.983005  Intel Core i5

# %%
df["Ram"].value_counts()
# Out:
# Ram
# 8     613
# 4     366
# 16    198
# 6      35
# 12     25
# 32     17
# 2      16
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
sns.barplot(df["Ram"].value_counts(), color="black")
plt.xticks(rotation=45)
plt.show()

# %%
# we have highest number of 8, 4 and 16 gb Ram laptops

# %%
sns.barplot(df, x = df["Ram"], y = df["Price"], hue=df["Ram"])
plt.show()

# %%
# from above we can see that price is directly proportinal to the RAM, as the Ram increases the prices are also increasing which is very obviuos

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\449318543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\687122208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head(3)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
#
#         Price  Touchscreen  IPS         ppi      CPU Brand
# 0  71378.6832            0    1  226.983005  Intel Core i5
# 1  47895.5232            0    0  127.677940  Intel Core i5
# 2  30636.0000            0    0  141.211998  Intel Core i5

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df["Memory"]
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1269              500GB HDD
# 1270              128GB SSD
# 1271              512GB SSD
# 1272     64GB Flash Storage
# 1273                1TB HDD
# Name: Memory, Length: 1274, dtype: object

# %%
# from above we will create the columns with having SSD, HDD, Flash Storage and Hybrid

# %%
type(df["Memory"])
# Out:
# pandas.core.series.Series

# %%
np.dtype(df["Memory"])
# Out:
# dtype('O')

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\562649780.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\562649780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)

# %%
# Remove 'GB' and replace 'TB' with '000' for standardizing memory sizes
df["Memory"] = df["Memory"].str.replace('GB', '', regex=False)
df["Memory"] = df["Memory"].str.replace('TB', '000', regex=False)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\3681813194.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"] = df["Memory"].str.replace('GB', '', regex=False)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\3681813194.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"] = df["Memory"].str.replace('TB', '000', regex=False)

# %%
# Split the 'Memory' column based on the "+" sign
new = df["Memory"].str.split("+", n=1, expand=True)

# %%
# Extract the first and second parts of the memory information
df["first"] = new[0].str.strip()
df["second"] = new[1].str.strip()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1085501259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"] = new[0].str.strip()
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1085501259.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["second"] = new[1].str.strip()

# %%
# Identify the type of storage in 'first'
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2678251424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2678251424.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2678251424.py:4: SettingWithCopyWarning:
# ...

# %%
# Remove non-numeric characters from 'first'
df['first'] = df['first'].str.replace(r'\D', '', regex=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2050600560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first'] = df['first'].str.replace(r'\D', '', regex=True)

# %%
# Handle missing 'second' values
df["second"].fillna("0", inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\422185729.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["second"].fillna("0", inplace=True)

# %%
# Identify the type of storage in 'second'
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\620264859.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\620264859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\620264859.py:4: SettingWithCopyWarning:
# ...

# %%
# Remove non-numeric characters from 'second'
df['second'] = df['second'].str.replace(r'\D', '', regex=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\407284784.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'] = df['second'].str.replace(r'\D', '', regex=True)

# %%
# Ensure that 'first' and 'second' are numeric
df["first"] = pd.to_numeric(df["first"], errors='coerce').fillna(0).astype(int)
df["second"] = pd.to_numeric(df["second"], errors='coerce').fillna(0).astype(int)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2019450203.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"] = pd.to_numeric(df["first"], errors='coerce').fillna(0).astype(int)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2019450203.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["second"] = pd.to_numeric(df["second"], errors='coerce').fillna(0).astype(int)

# %%
# Calculate total memory for each type of storage
df["HDD"] = df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"]
df["SSD"] = df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"]
df["Hybrid"] = df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"]
df["Flash_Storage"] = df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"]
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1345672866.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HDD"] = df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"]
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1345672866.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SSD"] = df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"]
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\1345672866.py:4: SettingWithCopyWarning:
# ...

# %%
# Drop unnecessary columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'], inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2566116714.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#               Memory                           Gpu  OpSys  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256 SSD         Intel HD Graphics 620  No OS    1.86
# 3            512 SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256 SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi      CPU Brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# ...

# %%
df["HDD"].value_counts()
# Out:
# HDD
# 0       715
# 1000    400
# 500     125
# 2000     32
# 32        1
# 128       1
# Name: count, dtype: int64

# %%
df["SSD"].value_counts()
# Out:
# SSD
# 256     498
# 0       437
# 128     170
# 512     134
# 1000     16
# 32        6
# 180       5
# 16        3
# 64        1
# 1024      1
# 768       1
# 240       1
# 8         1
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Ram              0.740106
# Weight           0.212192
# Price            1.000000
# Touchscreen      0.188631
# IPS              0.250358
# ppi              0.469539
# HDD             -0.098011
# SSD              0.669957
# Hybrid           0.022533
# Flash_Storage   -0.037176
# Name: Price, dtype: float64

# %%
# from above we can see ssd has good correlation with price
# with hard drive there is weak correlation with increase in hdd the price going low

# %%
# on hybrid and flash storage there is no direct correlation so we can drop them

# %%
df.drop(columns=["Hybrid", "Flash_Storage"], inplace=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2491481261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Hybrid", "Flash_Storage"], inplace=True)

# %%
df.head(2)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
#
#               Memory                           Gpu  OpSys  Weight       Price  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS    1.34  47895.5232
#
#    Touchscreen  IPS         ppi      CPU Brand  HDD  SSD
# 0            0    1  226.983005  Intel Core i5    0  128
# 1            0    0  127.677940  Intel Core i5    0    0

# %%
#Now at last we will handle the gpu column

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\2280560850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df["Gpu brand"].value_counts()
# Out:
# Gpu brand
# Intel     703
# Nvidia    396
# AMD       174
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df["Gpu brand"].value_counts()
# Out:
# Gpu brand
# Intel     703
# Nvidia    396
# AMD       174
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
#
#               Memory                           Gpu  OpSys  Weight       Price  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS    1.34  47895.5232
#
#    Touchscreen  IPS         ppi      CPU Brand  HDD  SSD Gpu brand
# 0            0    1  226.983005  Intel Core i5    0  128     Intel
# 1            0    0  127.677940  Intel Core i5    0    0     Intel

# %%
sns.barplot(df["Gpu brand"].value_counts())
# Out:
# <Axes: xlabel='Gpu brand', ylabel='count'>

# %%
sns.barplot(df, x = "Gpu brand", y = "Price", hue = "Gpu brand")
plt.show()

# %%
# as we can Nvidia gpu's has higher prices and intel gpu's has also higher prices than AMD gpu's

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(df, x = df["OpSys"], y = df["Price"], hue = df["OpSys"])
plt.xticks(rotation=45)
plt.show()

# %%
# now we can do is we can modeify this column by making all windows categories one and other accordingly

# %%
def fetch_OS(text):
    if text == "Windows 10" or text == "Windows 10 S" or text == "Windows 7":
        return "Windows"
    elif text == "macOS" or text == "Mac OS X":
        return "MAC"
    else:
        return "other No/Linux/Android"

# %%
df["OS"] = df["OpSys"].apply(fetch_OS)
df["OS"]
# Out:
# 0                          MAC
# 1                          MAC
# 2       other No/Linux/Android
# 3                          MAC
# 4                          MAC
#                  ...
# 1269                   Windows
# 1270                   Windows
# 1271                   Windows
# 1272                   Windows
# 1273                   Windows
# Name: OS, Length: 1273, dtype: object

# %%
df["OS"].value_counts()
# Out:
# OS
# Windows                   1100
# other No/Linux/Android     152
# MAC                         21
# Name: count, dtype: int64

# %%
sns.barplot(df["OS"].value_counts())
plt.show()

# %%
# we have higher number of windows laptops

# %%
sns.barplot(df, x = df["OS"], y = df["Price"], hue = df["OS"])
plt.show()

# %%
# above we can see that the MAC laptops has the higher prices then Windows then other laptops

# %%
df.head(1)
# Out:
#   Company   TypeName                    ScreenResolution  Ram   Memory  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8  128 SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
#
#           ppi      CPU Brand  HDD  SSD Gpu brand   OS
# 0  226.983005  Intel Core i5    0  128     Intel  MAC

# %%
df.drop(columns=["OpSys"], inplace=True)

# %%
df.head(2)
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
#
#               Memory                           Gpu  Weight       Price  \
# 0            128 SSD  Intel Iris Plus Graphics 640    1.37  71378.6832
# 1  128 Flash Storage        Intel HD Graphics 6000    1.34  47895.5232
#
#    Touchscreen  IPS         ppi      CPU Brand  HDD  SSD Gpu brand   OS
# 0            0    1  226.983005  Intel Core i5    0  128     Intel  MAC
# 1            0    0  127.677940  Intel Core i5    0    0     Intel  MAC

# %%
plt.hist(df["Weight"])
plt.show()

# %%
sns.distplot(df["Weight"], color="green")
plt.show()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\3976303167.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Weight"], color="green")

# %%
sns.scatterplot(df, x = df["Weight"], y = df["Price"], markers="*", color="red")
plt.show()

# %%
# there is slight relation in above as the weight increases the price is also increasing

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#               Memory                           Gpu  Weight        Price  \
# 0            128 SSD  Intel Iris Plus Graphics 640    1.37   71378.6832
# 1  128 Flash Storage        Intel HD Graphics 6000    1.34   47895.5232
# 2            256 SSD         Intel HD Graphics 620    1.86   30636.0000
# 3            512 SSD            AMD Radeon Pro 455    1.83  135195.3360
# 4            256 SSD  Intel Iris Plus Graphics 650    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU Brand  HDD  SSD Gpu brand  \
# 0            0    1  226.983005  Intel Core i5    0  128     Intel
# ...

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Ram            0.739996
# Weight         0.211667
# Price          1.000000
# Touchscreen    0.190382
# IPS            0.251514
# ppi            0.471481
# HDD           -0.098481
# SSD            0.669808
# Name: Price, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                   Ram    Weight     Price  Touchscreen       IPS       ppi  \
# Ram          1.000000  0.389134  0.739996     0.113316  0.202809  0.294927
# Weight       0.389134  1.000000  0.211667    -0.292288  0.023966 -0.319499
# Price        0.739996  0.211667  1.000000     0.190382  0.251514  0.471481
# Touchscreen  0.113316 -0.292288  0.190382     1.000000  0.136973  0.452107
# IPS          0.202809  0.023966  0.251514     0.136973  1.000000  0.288833
# ppi          0.294927 -0.319499  0.471481     0.452107  0.288833  1.000000
# HDD          0.097340  0.510876 -0.098481    -0.205105 -0.090411 -0.290774
# SSD          0.599552 -0.056984  0.669808     0.252142  0.215197  0.499899
#
#                   HDD       SSD
# Ram          0.097340  0.599552
# Weight       0.510876 -0.056984
# Price       -0.098481  0.669808
# Touchscreen -0.205105  0.252142
# IPS         -0.090411  0.215197
# ppi         -0.290774  0.499899
# HDD          1.000000 -0.400625
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
# from above we can see the correlations between the columns
# and we can find that there is no high correlation between the columns other than price which should be
# and HDD and weight has the good correlation as the HDD have more weights

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# we can make it normal for better results
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_14704\256694496.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# now we have done with the EDA part now we will move to prediction part

# %%
# lets gooooooooo

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        CPU Brand  HDD  SSD Gpu brand                      OS
# 0  Intel Core i5    0  128     Intel                     MAC
# 1  Intel Core i5    0    0     Intel                     MAC
# 2  Intel Core i5    0  256     Intel  other No/Linux/Android
# 3  Intel Core i7    0  512       AMD                     MAC
# 4  Intel Core i5    0  256     Intel                     MAC

# %%
X = df.drop(columns=["Price"])
y = np.log(df["Price"])

# %%
X.head(2)
# Out:
#   Company   TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34            0    0  127.677940
#
#        CPU Brand  HDD  SSD Gpu brand   OS
# 0  Intel Core i5    0  128     Intel  MAC
# 1  Intel Core i5    0    0     Intel  MAC

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1269    10.555257
# 1270    10.433899
# 1271    11.288115
# 1272     9.409283
# 1273    10.614129
# Name: Price, Length: 1273, dtype: float64

# %%
# above we made the price normal for the prediction later we will change it

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=23)

# %%
X_train
# Out:
#       Company     TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 802      Dell    Ultrabook    8    1.29            0    0  165.632118
# 1070     Dell     Notebook    4    2.06            0    0  100.454670
# 719        HP     Notebook    8    2.63            0    0  127.335675
# 1206       HP     Notebook    8    1.91            0    0  100.454670
# 45      Apple    Ultrabook    8    1.37            0    1  226.983005
# ...       ...          ...  ...     ...          ...  ...         ...
# 31       Asus     Notebook    2    1.65            0    0  111.935204
# 950        HP  Workstation    8    2.00            0    1  141.211998
# 1064      MSI       Gaming   16    1.80            0    0  141.211998
# 742   Toshiba     Notebook    8    1.25            1    1  157.350512
# 595    Lenovo     Notebook    8    2.29            0    0  100.454670
#
#           CPU Brand   HDD  SSD Gpu brand       OS
# 802   Intel Core i5     0  256     Intel  Windows
# ...

# %%
X_train.shape, X_test.shape
# Out:
# ((1082, 12), (191, 12))

# %%
X_train.head(2)
# Out:
#      Company   TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 802     Dell  Ultrabook    8    1.29            0    0  165.632118
# 1070    Dell   Notebook    4    2.06            0    0  100.454670
#
#           CPU Brand  HDD  SSD Gpu brand       OS
# 802   Intel Core i5    0  256     Intel  Windows
# 1070  Intel Core i3  500    0     Intel  Windows

# %%
# Now we will encode the categroical columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score , mean_absolute_error

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRFRegressor

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

lr = LinearRegression()

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("lr", lr)
])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('col_tnf',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 7, 10, 11])])),
#                 ('lr', LinearRegression())])

# %% [markdown]
# ## Linear Regression

# %%
y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8052904757842916
# MAE:  0.21292161590983066

# %%
np.exp(0.21)
# Out:
# 1.2336780599567432

# %%
# the error difference in price after prediction is just 1.22 rupees

# %% [markdown]
# ## Ridge Regression

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

ridge = Ridge(alpha=0.0005)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("ridge", ridge)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.805289835708219
# MAE:  0.2129218088159561

# %% [markdown]
# ## Lasso Regression

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

lasso = Lasso(alpha=0.001)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("lasso", lasso)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.7930210899144793
# MAE:  0.21971862464059377

# %% [markdown]
# ## Decision Tree Regressor

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# 83.39
dt = DecisionTreeRegressor(max_depth=10, min_samples_split=15, max_features=0.6)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("dt", dt)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8138246360605298
# MAE:  0.20565196531220967

# %% [markdown]
# ## Random Forest

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# Best trial accuracy: 0.8806162415724901
# Best hyperparameters: {'n_estimators': 273, 'max_depth': 16, 'random_state': 7, 'max_samples': 0.41553930134779377,
# 'max_features': 0.21668539753182536, 'bootstrap': False, 'min_samples_split': 4}

rfr = RandomForestRegressor(n_estimators=280,
                           random_state=8,
                           max_features=0.2,
                           max_depth=15, bootstrap=False, min_samples_split=4)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("rfr", rfr)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8751870985058192
# MAE:  0.1609808398624989

# %% [markdown]
# ## EXtra Trees Regressor

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

etr = ExtraTreesRegressor(n_estimators=285,
                           random_state=10,
                           max_features=0.3,
                           max_depth=15,
                         bootstrap=False, min_samples_split=3)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("etr", etr)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8716617909127644
# MAE:  0.1627658845915213

# %% [markdown]
# ## KNN and SVR

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

knn = KNeighborsRegressor(n_neighbors=3)
svr = SVR(kernel="rbf", C = 1000, epsilon=0.1)

pipe1 = Pipeline([
    ("col_tnf", col_tnf),
    ("knn", knn)
])

pipe2 = Pipeline([
    ("col_tnf", col_tnf),
    ("svr", svr)
])

pipe1.fit(X_train, y_train)
pipe2.fit(X_train, y_train)

y_pred = pipe1.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))

y_pred1 = pipe2.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred1))
print("MAE: ", mean_absolute_error(y_test, y_pred1))
# Out:
# R2 score:  0.750917976935968
# MAE:  0.22999040042996494
# R2 score:  0.7661774995488344
# MAE:  0.23366684820953854

# %% [markdown]
# ## Adaboost

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

adb = AdaBoostRegressor(n_estimators=200,learning_rate=0.8)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("adb", adb)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.7880421531610238
# MAE:  0.23211890187683473

# %% [markdown]
# ## Gradient Boost

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# Best hyperparameters: {'loss': 'huber', 'learning_rate': 0.07335528015656168, 'n_estimators': 1721, 'max_depth': 3, 
#                        'random_state': 7, 'min_samples_split': 4, 'min_samples_leaf': 2}

gbr = GradientBoostingRegressor(loss = "huber", n_estimators=2000, learning_rate=0.0733, max_depth=3,
                               random_state=3, min_samples_split=3, min_samples_leaf=2)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("gbr", gbr)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8716068828140694
# MAE:  0.15881044861403418

# %% [markdown]
# ## XgBoost

# %%
from xgboost import XGBRegressor

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# 87.90
xgb = XGBRFRegressor(n_estimators=300, max_depth=18, learning_rate=1.0,
                    subsample=0.75,  random_state=3)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("xgb", xgb)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score:  0.8790212735136493
# MAE:  0.15813618790885506

# %% [markdown]
# ## LightGBM Regressor

# %%
import lightgbm as lgb

col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

lgbm_reg = lgb.LGBMRegressor(num_leaves=40, learning_rate=0.2, n_estimators=125)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("light", lgbm_reg)
])


pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"R² score: {r2}")
print(f"MAE: {mae}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000464 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 209
# [LightGBM] [Info] Number of data points in the train set: 1082, number of used features: 25
# [LightGBM] [Info] Start training from score 10.833554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# ## CatBoost Regressor

# %%
from catboost import CatBoostRegressor

col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# Best trial accuracy: 0.8919282784647317
# Best hyperparameters: {'learning_rate': 0.1569295590189298, 'n_estimators': 277, 'depth': 6, 'l2_leaf_reg': 2}
catb = CatBoostRegressor(learning_rate=0.05, depth=9, l2_leaf_reg=1)
#catb = CatBoostRegressor(learning_rate=0.05, depth=9, l2_leaf_reg=2, n_estimators=2000)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("cat", catb)
])


pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"R² score: {r2}")
print(f"MAE: {mae}")
# Out:
# 0:	learn: 0.5968054	total: 12.8ms	remaining: 12.8s
# 1:	learn: 0.5757786	total: 21.1ms	remaining: 10.5s
# 2:	learn: 0.5553259	total: 26.8ms	remaining: 8.91s
# 3:	learn: 0.5364910	total: 32.3ms	remaining: 8.05s
# 4:	learn: 0.5179503	total: 37.3ms	remaining: 7.42s
# 5:	learn: 0.5019940	total: 40ms	remaining: 6.63s
# 6:	learn: 0.4857438	total: 43.1ms	remaining: 6.11s
# 7:	learn: 0.4706471	total: 47.8ms	remaining: 5.93s
# 8:	learn: 0.4575475	total: 51.9ms	remaining: 5.72s
# 9:	learn: 0.4449490	total: 53ms	remaining: 5.25s
# 10:	learn: 0.4315617	total: 56.8ms	remaining: 5.11s
# 11:	learn: 0.4194407	total: 58.9ms	remaining: 4.85s
# 12:	learn: 0.4080682	total: 63.2ms	remaining: 4.8s
# 13:	learn: 0.3977631	total: 67.1ms	remaining: 4.72s
# 14:	learn: 0.3881580	total: 71ms	remaining: 4.66s
# 15:	learn: 0.3790590	total: 75ms	remaining: 4.62s
# 16:	learn: 0.3690564	total: 78.9ms	remaining: 4.57s
# 17:	learn: 0.3594202	total: 82.9ms	remaining: 4.52s
# ...

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"),[0,1,7,10,11])
], remainder="passthrough")

gb = GradientBoostingRegressor()

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("gb", gb)
])

# %%
param_dist = {
    'gb__n_estimators': (50, 100, 500, 1000, 2000),
    'gb__learning_rate': (0.5, 1.0, 0.05, 0.2),  # Logarithmic scale for smaller values
    'gb__max_depth': (3, 5, 8, 10, 11),
    'gb__min_samples_split': (2, 5, 11),
    'gb__min_samples_leaf': (1, 3, 6)
}

random_search = RandomizedSearchCV(
    estimator=pipe,
    param_distributions=param_dist,
    n_iter=50,  # Number of different combinations to try
    scoring='neg_mean_squared_error',  # Scoring metric (e.g., for regression)
    cv=10,  # 5-fold cross-validation
    random_state=42,
    n_jobs=-1,  # Use all available cores
    verbose=1  # Show progress
)

# %%
random_search.fit(X_train, y_train)

# Get the best model and its parameters
print("Best parameters found: ", random_search.best_params_)
best_model = random_search.best_estimator_
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Best parameters found:  {'gb__n_estimators': 50, 'gb__min_samples_split': 11, 'gb__min_samples_leaf': 3, 'gb__max_depth': 5, 'gb__learning_rate': 0.5}
# C:\Users\kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(

# %%
y_pred = best_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"R² Score: {r2:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# R² Score: 0.8528
# MAE: 0.1650

# %% [markdown]
# ## for xgboost

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

xgb = XGBRFRegressor()

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("xgb", xgb)
])

param_dist = {
    'xgb__n_estimators': (50, 100, 450, 500),
    'xgb__learning_rate': np.logspace(-3, 0, 10, 0.5),
    'xgb__max_depth': np.arange(3, 5, 10),
    'xgb__min_child_weight': np.arange(1, 6),
    'xgb__gamma': np.linspace(0, 0.5, 5),
    'xgb__colsample_bytree': np.linspace(0.6, 1.0, 5),
    'xgb__reg_alpha': np.logspace(-3, 1, 10),  # L1 regularization
    'xgb__reg_lambda': np.logspace(-3, 1, 10)  # L2 regularization
}

random_search = RandomizedSearchCV(
    estimator=pipe,
    param_distributions=param_dist,
    n_iter=50,  # Number of different combinations to try
    scoring='neg_mean_squared_error',  # Scoring metric (e.g., for regression)
    cv=10,  # 5-fold cross-validation
    random_state=42,
    n_jobs=-1,  # Use all available cores
    verbose=1  # Show progress
)

# %%
random_search.fit(X_train, y_train)

# Get the best model and its parameters
print("Best parameters found: ", random_search.best_params_)
best_model = random_search.best_estimator_

y_pred = best_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"R² Score: {r2:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# C:\Users\kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# Best parameters found:  {'xgb__reg_lambda': 3.593813663804626, 'xgb__reg_alpha': 0.1668100537200059, 'xgb__n_estimators': 500, 'xgb__min_child_weight': 5, 'xgb__max_depth': 3, 'xgb__learning_rate': 0.001, 'xgb__gamma': 0.125, 'xgb__colsample_bytree': 0.7}
# R² Score: -0.0019
# MAE: 0.5189

# %% [markdown]
# ## For Gradient Boosting

# %%
from sklearn.model_selection import GridSearchCV

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

gbr = GradientBoostingRegressor()

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("gbr", gbr)
])

GradientBoostingRegressor(n_estimators=2000, learning_rate=0.09, max_depth=3)

param_grid = {
    'gbr__learning_rate': [0.01, 0.05, 0.1, 0.09],
    'gbr__n_estimators': [100, 300, 500, 2000],
    'gbr__max_depth': [3, 5, 7],
    'gbr__min_samples_split': [2, 5, 10],
    'gbr__min_samples_leaf': [1, 3, 5],
    'gbr__subsample': [0.7, 0.8, 1.0]
}

random_search = RandomizedSearchCV(estimator=pipe, param_distributions=param_grid, n_iter=20, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
random_search.fit(X_train, y_train)
# Out:
# C:\Users\kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
#   warnings.warn(
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('col_tnf',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('tnf',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              sparse_output=False),
#                                                                                [0,
#                                                                                 1,
# ...

# %%
# Get the best model and its parameters
print("Best parameters found: ", random_search.best_params_)
best_model = random_search.best_estimator_

y_pred = best_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"R² Score: {r2:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Best parameters found:  {'gbr__subsample': 0.7, 'gbr__n_estimators': 300, 'gbr__min_samples_split': 10, 'gbr__min_samples_leaf': 5, 'gbr__max_depth': 7, 'gbr__learning_rate': 0.01}
# R² Score: 0.8535
# MAE: 0.1717

# %%
X_train.head(1)
# Out:
#     Company   TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 802    Dell  Ultrabook    8    1.29            0    0  165.632118
#
#          CPU Brand  HDD  SSD Gpu brand       OS
# 802  Intel Core i5    0  256     Intel  Windows

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1082 entries, 802 to 595
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1082 non-null   object
#  1   TypeName     1082 non-null   object
#  2   Ram          1082 non-null   int32
#  3   Weight       1082 non-null   float32
#  4   Touchscreen  1082 non-null   int64
#  5   IPS          1082 non-null   int64
#  6   ppi          1082 non-null   float64
#  7   CPU Brand    1082 non-null   object
#  8   HDD          1082 non-null   int64
#  9   SSD          1082 non-null   int64
#  10  Gpu brand    1082 non-null   object
#  11  OS           1082 non-null   object
# dtypes: float32(1), float64(1), int32(1), int64(4), object(5)
# memory usage: 101.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1273
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int32
#  3   Weight       1273 non-null   float32
#  4   Price        1273 non-null   float64
#  5   Touchscreen  1273 non-null   int64
#  6   IPS          1273 non-null   int64
#  7   ppi          1273 non-null   float64
#  8   CPU Brand    1273 non-null   object
#  9   HDD          1273 non-null   int64
#  10  SSD          1273 non-null   int64
#  11  Gpu brand    1273 non-null   object
#  12  OS           1273 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 129.3+ KB

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor

# %%
col_tnf = ColumnTransformer(transformers=[
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# 0.8751
rfr = RandomForestRegressor(n_estimators=280,
                           random_state=8,
                           max_features=0.2,
                           max_depth=15, bootstrap=False, min_samples_split=4)

# 0.8716
etr = ExtraTreesRegressor(n_estimators=285,
                           random_state=10,
                           max_features=0.3,
                           max_depth=15,
                         bootstrap=False, min_samples_split=3)
# 0.87160
gbr = GradientBoostingRegressor(loss = "huber", n_estimators=2000, learning_rate=0.0733, max_depth=3,
                               random_state=3, min_samples_split=3, min_samples_leaf=2)

# 87.90
xgb = XGBRFRegressor(n_estimators=300, max_depth=18, learning_rate=1.0,
                    subsample=0.75,  random_state=3)

# 0.8828
catb = CatBoostRegressor(learning_rate=0.05, depth=9, l2_leaf_reg=1)

# 0.8740
lgbm_reg = lgb.LGBMRegressor(num_leaves=40, learning_rate=0.2, n_estimators=125)

# ("rfr", rfr), ("gbr", gbr)

# 89.74
# vote = VotingRegressor([("rfr", rfr), ("gbr", gbr), ("catb", catb), ("lgbm", lgbm_reg)],  weights=[10,6,20,10])
vote = VotingRegressor([("rfr", rfr), ("xgb", xgb), ("catb", catb), ("lgbm_reg", lgbm_reg)],  weights=[7,12,16, 6])

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("vote", vote)
])

pipe.fit(X_train,y_train)
# Out:
# 0:	learn: 0.5968054	total: 2.89ms	remaining: 2.89s
# 1:	learn: 0.5757786	total: 7.75ms	remaining: 3.87s
# 2:	learn: 0.5553259	total: 12.5ms	remaining: 4.16s
# 3:	learn: 0.5364910	total: 17.2ms	remaining: 4.29s
# 4:	learn: 0.5179503	total: 22ms	remaining: 4.38s
# 5:	learn: 0.5019940	total: 24.8ms	remaining: 4.11s
# 6:	learn: 0.4857438	total: 27.6ms	remaining: 3.91s
# 7:	learn: 0.4706471	total: 32.3ms	remaining: 4s
# 8:	learn: 0.4575475	total: 36.7ms	remaining: 4.04s
# 9:	learn: 0.4449490	total: 38ms	remaining: 3.76s
# 10:	learn: 0.4315617	total: 42.4ms	remaining: 3.81s
# 11:	learn: 0.4194407	total: 44.5ms	remaining: 3.66s
# 12:	learn: 0.4080682	total: 48.9ms	remaining: 3.71s
# 13:	learn: 0.3977631	total: 53.4ms	remaining: 3.76s
# 14:	learn: 0.3881580	total: 58ms	remaining: 3.81s
# 15:	learn: 0.3790590	total: 62ms	remaining: 3.81s
# 16:	learn: 0.3690564	total: 66.2ms	remaining: 3.83s
# 17:	learn: 0.3594202	total: 69.9ms	remaining: 3.81s
# ...

# %%
y_pred = pipe.predict(X_test)

print('R2 score',np.round(r2_score(y_test,y_pred),5))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.88834
# MAE 0.1494829331617053

# %%
# pickle.dump(df, open("df.pkl", "wb"))
# pickle.dump(pipe, open("model.pkl", "wb"))

# %% [markdown]
# ## Stacking Regressor

# %%
from sklearn.ensemble import StackingRegressor

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# 0.8751
rfr = RandomForestRegressor(n_estimators=280,
                           random_state=8,
                           max_features=0.2,
                           max_depth=15, bootstrap=False, min_samples_split=4)

# 0.8716
etr = ExtraTreesRegressor(n_estimators=285,
                           random_state=10,
                           max_features=0.3,
                           max_depth=15,
                         bootstrap=False, min_samples_split=3)
# 0.87160
gbr = GradientBoostingRegressor(loss = "huber", n_estimators=2000, learning_rate=0.0733, max_depth=3,
                               random_state=3, min_samples_split=3, min_samples_leaf=2)

# 87.90
xgb = XGBRFRegressor(n_estimators=300, max_depth=18, learning_rate=1.0,
                    subsample=0.75,  random_state=3)

# 0.8828
catb = CatBoostRegressor(learning_rate=0.05, depth=9, l2_leaf_reg=1)

# 0.8740
lgbm_reg = lgb.LGBMRegressor(num_leaves=40, learning_rate=0.2, n_estimators=125)

estimators = [
    ("rfr", rfr),
    ("xgb", xgb),
    ("catb", catb),
    ("lgbm", lgbm_reg)
]

stack = StackingRegressor(estimators=estimators, final_estimator=LinearRegression())

pipe1 = Pipeline([
    ("col_tnf", col_tnf),
    ("stack", stack)
])

pipe1.fit(X_train,y_train)
# Out:
# 0:	learn: 0.5968054	total: 2.79ms	remaining: 2.79s
# 1:	learn: 0.5757786	total: 7.44ms	remaining: 3.71s
# 2:	learn: 0.5553259	total: 13ms	remaining: 4.33s
# 3:	learn: 0.5364910	total: 18ms	remaining: 4.47s
# 4:	learn: 0.5179503	total: 23ms	remaining: 4.57s
# 5:	learn: 0.5019940	total: 26.3ms	remaining: 4.36s
# 6:	learn: 0.4857438	total: 29.8ms	remaining: 4.23s
# 7:	learn: 0.4706471	total: 34.5ms	remaining: 4.28s
# 8:	learn: 0.4575475	total: 39.4ms	remaining: 4.34s
# 9:	learn: 0.4449490	total: 40.7ms	remaining: 4.03s
# 10:	learn: 0.4315617	total: 45.8ms	remaining: 4.12s
# 11:	learn: 0.4194407	total: 48.1ms	remaining: 3.96s
# 12:	learn: 0.4080682	total: 52.6ms	remaining: 3.99s
# 13:	learn: 0.3977631	total: 57.7ms	remaining: 4.06s
# 14:	learn: 0.3881580	total: 63.3ms	remaining: 4.16s
# 15:	learn: 0.3790590	total: 68.1ms	remaining: 4.18s
# 16:	learn: 0.3690564	total: 74.2ms	remaining: 4.29s
# 17:	learn: 0.3594202	total: 79.4ms	remaining: 4.33s
# ...

# %%
y_pred = pipe1.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8847699738095838
# MAE 0.15030640476464305

# %%
from sklearn.model_selection import cross_val_score

# Use cross-validation to get the average R² score
cv_scores = cross_val_score(pipe, X_train, y_train, cv=5, scoring='r2')
print(f"Cross-validated R² score: {cv_scores.mean()}")
# Out:
# 0:	learn: 0.5989996	total: 4.5ms	remaining: 4.49s
# 1:	learn: 0.5793231	total: 8.38ms	remaining: 4.18s
# 2:	learn: 0.5584224	total: 12ms	remaining: 3.98s
# 3:	learn: 0.5395708	total: 15.6ms	remaining: 3.89s
# 4:	learn: 0.5200990	total: 19.5ms	remaining: 3.87s
# 5:	learn: 0.5033297	total: 23.1ms	remaining: 3.83s
# 6:	learn: 0.4867863	total: 26.8ms	remaining: 3.8s
# 7:	learn: 0.4703852	total: 30.4ms	remaining: 3.77s
# 8:	learn: 0.4549352	total: 34.1ms	remaining: 3.75s
# 9:	learn: 0.4408276	total: 37.8ms	remaining: 3.74s
# 10:	learn: 0.4276672	total: 41.4ms	remaining: 3.72s
# 11:	learn: 0.4155034	total: 43.5ms	remaining: 3.58s
# 12:	learn: 0.4043782	total: 47.2ms	remaining: 3.59s
# 13:	learn: 0.3930241	total: 50.9ms	remaining: 3.58s
# 14:	learn: 0.3818268	total: 54.5ms	remaining: 3.58s
# 15:	learn: 0.3720935	total: 58.1ms	remaining: 3.57s
# 16:	learn: 0.3615703	total: 61.7ms	remaining: 3.57s
# 17:	learn: 0.3544992	total: 63.1ms	remaining: 3.44s
# ...

# %%
import optuna
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %%
df.head(2)
# Out:
#   Company   TypeName  Ram  Weight       Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34  47895.5232            0    0  127.677940
#
#        CPU Brand  HDD  SSD Gpu brand   OS
# 0  Intel Core i5    0  128     Intel  MAC
# 1  Intel Core i5    0    0     Intel  MAC

# %%
df["Company"].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        8
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %% [markdown]
# ## Random Forest With Optuna

# %%
# rfr = RandomForestRegressor(n_estimators=280,
#                            random_state=4,
#                            max_features=0.3,
#                            max_depth=26, bootstrap=False, min_samples_split=3)

# Define the objective function
def objective(trial):
    # Suggest values for the hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 200, 300)
    max_depth = trial.suggest_int('max_depth', 15, 30)
    random_state = trial.suggest_int("random_state", 1, 10)
    max_samples = trial.suggest_float("max_samples", 0.1, 1.0)
    max_features = trial.suggest_float("max_features", 0.2, 0.9)
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])
    min_samples_split = trial.suggest_int("min_samples_split", 2, 9)
    
    # Create the RandomForestClassifier with suggested hyperparameters
    rfr = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=random_state,
        max_features = max_features,
        bootstrap = bootstrap,
        min_samples_split = min_samples_split
    )

    col_tnf = ColumnTransformer([
        ("tnf", OneHotEncoder(sparse_output=False, handle_unknown = "ignore", drop="first"), [0,1,7,10,11])], remainder="passthrough")

    pipe1 = Pipeline([
        ("col_tnf", col_tnf),
        ("rfr", rfr)])

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(pipe1, X_train, y_train, cv=5, scoring='r2').mean()
    # score = model.predict(X_test)

    return score  # Return the accuracy score for Optuna to maximize

# %%
# # Create a study object and optimize the objective function
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())  # We aim to maximize accuracy
# study.optimize(objective, n_trials=100)  # Run 50 trials to find the best hyperparameters

# %%
# Print the best result
print(f'Best trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Best trial accuracy: 0.8715474267273491
# Best hyperparameters: {'learning_rate': 0.22789834270265455, 'n_estimators': 312, 'max_depth': 3, 'num_leaves': 41}

# %% [markdown]
# ## Extra Trees With Optuna

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
# etr = ExtraTreesRegressor(n_estimators=340,
#                            random_state=2,
#                            max_features=0.3,
#                            max_depth=18,
#                          bootstrap=False, min_samples_split=3)

# Define the objective function
def objective_etr(trial):
    # Suggest values for the hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 300, 400)
    max_depth = trial.suggest_int('max_depth', 10, 30)
    random_state = trial.suggest_int("random_state", 1, 10)
    max_samples = trial.suggest_float("max_samples", 0.1, 1.0)
    max_features = trial.suggest_float("max_features", 0.2, 0.9)
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])
    min_samples_split = trial.suggest_int("min_samples_split", 2, 9)
    
    # Create the RandomForestClassifier with suggested hyperparameters
    etr = ExtraTreesRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=random_state,
        max_features = max_features,
        bootstrap = bootstrap,
        min_samples_split = min_samples_split
    )

    col_tnf = ColumnTransformer([
        ("tnf", OneHotEncoder(sparse_output=False, handle_unknown = "ignore", drop="first"), [0,1,7,10,11])], remainder="passthrough")

    pipe1 = Pipeline([
        ("col_tnf", col_tnf),
        ("etr", etr)])

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(pipe1, X_train, y_train, cv=5, scoring='r2').mean()
    # score = model.predict(X_test)

    return score  # Return the accuracy score for Optuna to maximize

# %%
# # Create a study object and optimize the objective function
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())  # We aim to maximize accuracy
# study.optimize(objective_etr, n_trials=100)  # Run 50 trials to find the best hyperparameters

# %%
# Print the best result
print(f'Best trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Best trial accuracy: 0.8715474267273491
# Best hyperparameters: {'learning_rate': 0.22789834270265455, 'n_estimators': 312, 'max_depth': 3, 'num_leaves': 41}

# %% [markdown]
# ## Gradient descent with Optuna

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GradientBoostingRegressor(n_estimators=2000, learning_rate=0.09, max_depth=3)

param_grid = {
    'gbr__learning_rate': [0.01, 0.05, 0.1, 0.09],
    'gbr__n_estimators': [100, 300, 500, 2000],
    'gbr__max_depth': [3, 5, 7],
    'gbr__min_samples_split': [2, 5, 10],
    'gbr__min_samples_leaf': [1, 3, 5],
    'gbr__subsample': [0.7, 0.8, 1.0]
}

def objective_gbr(trial):
    # Suggest values for the hyperparameters
    loss = trial.suggest_categorical("loss", ["squared_error", "absolute_error", "huber", "quantile"])
    learning_rate = trial.suggest_float("learning_rate", 0.01, 1.0)
    n_estimators = trial.suggest_int('n_estimators', 100, 2000)
    max_depth = trial.suggest_int('max_depth', 2, 15)
    random_state = trial.suggest_int("random_state", 1, 10)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 9)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 10)
    
    # Create the RandomForestClassifier with suggested hyperparameters
    gbr = GradientBoostingRegressor(
        loss = loss,
        learning_rate = learning_rate,
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=random_state,
        min_samples_leaf = min_samples_leaf,
        min_samples_split = min_samples_split
    )

    col_tnf = ColumnTransformer([
        ("tnf", OneHotEncoder(sparse_output=False, handle_unknown = "ignore", drop="first"), [0,1,7,10,11])], remainder="passthrough")

    pipe1 = Pipeline([
        ("col_tnf", col_tnf),
        ("gbr", gbr)])

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(pipe1, X_train, y_train, cv=5, scoring='r2').mean()
    # score = model.predict(X_test)

    return score  # Return the accuracy score for Optuna to maximize

# %%
# # Create a study object and optimize the objective function
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())  # We aim to maximize accuracy
# study.optimize(objective_gbr, n_trials=100)  # Run 50 trials to find the best hyperparameters

# %%
# Print the best result
# print(f'Best trial accuracy: {study.best_trial.value}')
# print(f'Best hyperparameters: {study.best_trial.params}')

# %% [markdown]
# ## Xgboost with Optuna

# %%
from xgboost import XGBRFRegressor

# %%
# xgb = XGBRFRegressor(n_estimators=300, max_depth=25, learning_rate=1.0,
#                     subsample=0.75, n_jobs=4, random_state=3)

# param_dist = {
#     'xgb__n_estimators': (50, 100, 450, 500),
#     'xgb__learning_rate': np.logspace(-3, 0, 10, 0.5),
#     'xgb__max_depth': np.arange(3, 5, 10),
#     'xgb__min_child_weight': np.arange(1, 6),
#     'xgb__gamma': np.linspace(0, 0.5, 5),
#     'xgb__colsample_bytree': np.linspace(0.6, 1.0, 5),
#     'xgb__reg_alpha': np.logspace(-3, 1, 10),  # L1 regularization
#     'xgb__reg_lambda': np.logspace(-3, 1, 10)  # L2 regularization

def objective_xgb(trial):
    # Suggest values for the hyperparameters
    learning_rate = trial.suggest_float("learning_rate", 0.01, 1.0)
    n_estimators = trial.suggest_int('n_estimators', 50, 1000)
    max_depth = trial.suggest_int('max_depth', 2, 15)
    random_state = trial.suggest_int("random_state", 1, 10)
    min_child_weight = trial.suggest_int("min_child_weight", 1, 9)
    gamma = trial.suggest_int("gamma'", 1, 5)
    subsample = trial.suggest_int("subsample", 0.1, 0.9)
    n_jobs = trial.suggest_int("n_jobs", 2, 8)
    
    
    # Create the RandomForestClassifier with suggested hyperparameters
    xgb = XGBRFRegressor(
        learning_rate = learning_rate,
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=random_state,
        gamma = gamma
    )

    col_tnf = ColumnTransformer([
        ("tnf", OneHotEncoder(sparse_output=False, handle_unknown = "ignore", drop="first"), [0,1,7,10,11])], remainder="passthrough")

    pipe1 = Pipeline([
        ("col_tnf", col_tnf),
        ("xgb", xgb)])

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(pipe1, X_train, y_train, cv=5, scoring='r2').mean()
    # score = model.predict(X_test)

    return score  # Return the accuracy score for Optuna to maximize

# %%
# # Create a study object and optimize the objective function
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())  # We aim to maximize accuracy
# study.optimize(objective_xgb, n_trials=100)  # Run 50 trials to find the best hyperparameters

# %%
#Print the best result
print(f'Best trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Best trial accuracy: 0.8715474267273491
# Best hyperparameters: {'learning_rate': 0.22789834270265455, 'n_estimators': 312, 'max_depth': 3, 'num_leaves': 41}

# %% [markdown]
# # lightgbm with Optuna

# %%
# lgbm_reg = lgb.LGBMRegressor(num_leaves=40, learning_rate=0.2, n_estimators=125)
from lightgbm import LGBMRegressor

def objective_lgb(trial):
    # Suggest values for the hyperparameters
    learning_rate = trial.suggest_float("learning_rate", 0.01, 1.0)
    n_estimators = trial.suggest_int('n_estimators', 50, 500)
    max_depth = trial.suggest_int('max_depth', 2, 15)
    num_leaves = trial.suggest_int("num_leaves", 20, 50)
    
    
    # Create the RandomForestClassifier with suggested hyperparameters
    lgb = LGBMRegressor(
        learning_rate = learning_rate,
        n_estimators=n_estimators,
        max_depth=max_depth,
        num_leaves = num_leaves
    )

    col_tnf = ColumnTransformer([
        ("tnf", OneHotEncoder(sparse_output=False, handle_unknown = "ignore", drop="first"), [0,1,7,10,11])], remainder="passthrough")

    pipe1 = Pipeline([
        ("col_tnf", col_tnf),
        ("lgb", lgb)])

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(pipe1, X_train, y_train, cv=5, scoring='r2').mean()
    # score = model.predict(X_test)

    return score  # Return the accuracy score for Optuna to maximize

# %%
# # Create a study object and optimize the objective function
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())  # We aim to maximize accuracy
# study.optimize(objective_lgb, n_trials=100)  # Run 50 trials to find the best hyperparameters

# %%
#Print the best result
print(f'Best trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Best trial accuracy: 0.8715474267273491
# Best hyperparameters: {'learning_rate': 0.22789834270265455, 'n_estimators': 312, 'max_depth': 3, 'num_leaves': 41}

# %% [markdown]
# ## Catboost with Optuna

# %%
from catboost import CatBoostRegressor

# %%
# catb = CatBoostRegressor(learning_rate=0.05, depth=9, l2_leaf_reg=1)

def objective_cat(trial):
    # Suggest values for the hyperparameters
    learning_rate = trial.suggest_float("learning_rate", 0.01, 1.0)
    n_estimators = trial.suggest_int('n_estimators', 50, 500)
    depth = trial.suggest_int('depth', 2, 15)
    l2_leaf_reg = trial.suggest_int("l2_leaf_reg", 1, 5)
    
    
    # Create the RandomForestClassifier with suggested hyperparameters
    cat = CatBoostRegressor(
        learning_rate = learning_rate,
        n_estimators=n_estimators,
        depth=depth,
        l2_leaf_reg = l2_leaf_reg
    )

    col_tnf = ColumnTransformer([
        ("tnf", OneHotEncoder(sparse_output=False, handle_unknown = "ignore", drop="first"), [0,1,7,10,11])], remainder="passthrough")

    pipe1 = Pipeline([
        ("col_tnf", col_tnf),
        ("cat", cat)])

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(pipe1, X_train, y_train, cv=5, scoring='r2').mean()
    # score = model.predict(X_test)

    return score  # Return the accuracy score for Optuna to maximize

# %%
# # Create a study object and optimize the objective function
# study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())  # We aim to maximize accuracy
# study.optimize(objective_cat, n_trials=100)  # Run 50 trials to find the best hyperparameters

# %%
#Print the best result
print(f'Best trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Best trial accuracy: 0.8715474267273491
# Best hyperparameters: {'learning_rate': 0.22789834270265455, 'n_estimators': 312, 'max_depth': 3, 'num_leaves': 41}

# %%
col_tnf = ColumnTransformer([
    ("tnf", OneHotEncoder(sparse_output=False, handle_unknown = "ignore", drop="first"), [0,1,7,10,11])
], remainder="passthrough")

cat = CatBoostRegressor(learning_rate = 0.1569295590189298, n_estimators =  277, depth = 6, l2_leaf_reg = 2)

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("cat", cat)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# 0:	learn: 0.5527139	total: 1.47ms	remaining: 406ms
# 1:	learn: 0.4981651	total: 2.93ms	remaining: 402ms
# 2:	learn: 0.4510983	total: 4.32ms	remaining: 395ms
# 3:	learn: 0.4178658	total: 5.81ms	remaining: 397ms
# 4:	learn: 0.3846986	total: 7.03ms	remaining: 382ms
# 5:	learn: 0.3579617	total: 8.35ms	remaining: 377ms
# 6:	learn: 0.3338465	total: 9.63ms	remaining: 371ms
# 7:	learn: 0.3149003	total: 11ms	remaining: 368ms
# 8:	learn: 0.3003673	total: 12.3ms	remaining: 366ms
# 9:	learn: 0.2883558	total: 13.6ms	remaining: 363ms
# 10:	learn: 0.2770171	total: 14.8ms	remaining: 358ms
# 11:	learn: 0.2668521	total: 16.1ms	remaining: 356ms
# 12:	learn: 0.2600460	total: 17.5ms	remaining: 356ms
# 13:	learn: 0.2550335	total: 18.8ms	remaining: 354ms
# 14:	learn: 0.2494762	total: 20.3ms	remaining: 354ms
# 15:	learn: 0.2433356	total: 21.5ms	remaining: 351ms
# 16:	learn: 0.2379016	total: 22.8ms	remaining: 348ms
# 17:	learn: 0.2349264	total: 23.9ms	remaining: 345ms
# ...

# %% [markdown]
# # By Using Optuna

# %%
# Random Forest 
# Best trial accuracy: 0.8806162415724901
# Best hyperparameters: {'n_estimators': 273, 'max_depth': 16, 'random_state': 7, 'max_samples': 0.41553930134779377, 
#                        'max_features': 0.21668539753182536, 'bootstrap': False, 'min_samples_split': 4}


# Extra trees
# Best trial accuracy: 0.8756322169959713
# Best hyperparameters: {'n_estimators': 326, 'max_depth': 15, 'random_state': 4, 'max_samples': 0.31948951802733455,
#                        'max_features': 0.24810913270553953, 'bootstrap': False, 'min_samples_split': 3}


# Gradient boosting
# Best trial accuracy: 0.883829411750742
# Best hyperparameters: {'loss': 'huber', 'learning_rate': 0.07335528015656168, 'n_estimators': 1721, 'max_depth': 3, 
#                        'random_state': 7, 'min_samples_split': 4, 'min_samples_leaf': 2}

# xgboost
# 87.79
#xgb = XGBRFRegressor(n_estimators=300, max_depth=25, learning_rate=1.0, subsample=0.75, n_jobs=4, random_state=3)

# lightgbm
# 87.23
## lgbm_reg = lgb.LGBMRegressor(num_leaves=40, learning_rate=0.2, n_estimators=125)

#catboost
# Best trial accuracy: 0.8919282784647317
# Best hyperparameters: {'learning_rate': 0.1569295590189298, 'n_estimators': 277, 'depth': 6, 'l2_leaf_reg': 2}

# %%
col_tnf = ColumnTransformer(transformers=[
    ("tnf", OneHotEncoder(sparse_output=False, drop="first", handle_unknown='ignore'), [0,1,7,10,11])
], remainder="passthrough")

rfr = RandomForestRegressor(n_estimators=326,
                           random_state=4,
                           max_features=0.2166,
                           max_depth=15, bootstrap=False, min_samples_split=4)

etr = ExtraTreesRegressor(n_estimators=340,
                          
                           random_state=2,
                           max_features=0.2481,
                           max_depth=18,
                         bootstrap=False, min_samples_split=3)

xgb = XGBRFRegressor(n_estimators=300, max_depth=25, learning_rate=1.0, subsample=0.75, n_jobs=4, random_state=3)

gbr = GradientBoostingRegressor(n_estimators=1721, loss = "huber", learning_rate=0.0733, max_depth=3,
                               random_state=7, min_samples_split=4, min_samples_leaf=3)

catb = CatBoostRegressor(learning_rate=0.1569, depth=6, l2_leaf_reg=2, n_estimators=277 )

lgbm_reg = lgb.LGBMRegressor(num_leaves=40, learning_rate=0.2, n_estimators=125)

# ("rfr", rfr), ("gbr", gbr)

# 89.74
# vote = VotingRegressor([("rfr", rfr), ("gbr", gbr), ("catb", catb), ("lgbm", lgbm_reg)],  weights=[10,6,20,10])
vote = VotingRegressor([("gbr", gbr), ("catb", catb)],  weights=[12,20])

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("vote", vote)
])

pipe.fit(X_train,y_train)
# Out:
# 0:	learn: 0.5527260	total: 1.73ms	remaining: 477ms
# 1:	learn: 0.4981852	total: 3.28ms	remaining: 451ms
# 2:	learn: 0.4511235	total: 4.51ms	remaining: 412ms
# 3:	learn: 0.4178932	total: 5.63ms	remaining: 384ms
# 4:	learn: 0.3847268	total: 6.62ms	remaining: 360ms
# 5:	learn: 0.3579899	total: 7.6ms	remaining: 343ms
# 6:	learn: 0.3338739	total: 8.78ms	remaining: 339ms
# 7:	learn: 0.3149260	total: 9.94ms	remaining: 334ms
# 8:	learn: 0.3003917	total: 11.1ms	remaining: 332ms
# 9:	learn: 0.2883787	total: 12.4ms	remaining: 331ms
# 10:	learn: 0.2770383	total: 13.5ms	remaining: 326ms
# 11:	learn: 0.2668721	total: 14.4ms	remaining: 319ms
# 12:	learn: 0.2600640	total: 15.4ms	remaining: 313ms
# 13:	learn: 0.2550498	total: 16.4ms	remaining: 309ms
# 14:	learn: 0.2494917	total: 17.7ms	remaining: 309ms
# 15:	learn: 0.2433496	total: 18.7ms	remaining: 304ms
# 16:	learn: 0.2379145	total: 19.7ms	remaining: 302ms
# 17:	learn: 0.2349387	total: 20.7ms	remaining: 298ms
# ...

# %%
y_pred = pipe.predict(X_test)

print('R2 score',np.round(r2_score(y_test,y_pred),5))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.87764
# MAE 0.1549496605349943

# %%
X_train.head(1)
# Out:
#     Company   TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 802    Dell  Ultrabook    8    1.29            0    0  165.632118
#
#          CPU Brand  HDD  SSD Gpu brand       OS
# 802  Intel Core i5    0  256     Intel  Windows

# %% [markdown]
# ## EXport the Model

# %%
col_tnf = ColumnTransformer(transformers=[
    ("tnf", OneHotEncoder(sparse_output=False, handle_unknown="ignore", drop="first"), [0,1,7,10,11])
], remainder="passthrough")

# 0.8751
rfr = RandomForestRegressor(n_estimators=280,
                           random_state=8,
                           max_features=0.2,
                           max_depth=15, bootstrap=False, min_samples_split=4)

# 0.8716
etr = ExtraTreesRegressor(n_estimators=285,
                           random_state=10,
                           max_features=0.3,
                           max_depth=15,
                         bootstrap=False, min_samples_split=3)
# 0.87160
gbr = GradientBoostingRegressor(loss = "huber", n_estimators=2000, learning_rate=0.0733, max_depth=3,
                               random_state=3, min_samples_split=3, min_samples_leaf=2)

# 87.90
xgb = XGBRFRegressor(n_estimators=300, max_depth=18, learning_rate=1.0,
                    subsample=0.75,  random_state=3)

# 0.8828
catb = CatBoostRegressor(learning_rate=0.05, depth=9, l2_leaf_reg=1)

# 0.8740
lgbm_reg = lgb.LGBMRegressor(num_leaves=40, learning_rate=0.2, n_estimators=125)

# ("rfr", rfr), ("gbr", gbr)

# 89.74
# vote = VotingRegressor([("rfr", rfr), ("gbr", gbr), ("catb", catb), ("lgbm", lgbm_reg)],  weights=[10,6,20,10])
vote = VotingRegressor([("rfr", rfr), ("xgb", xgb), ("catb", catb), ("lgbm_reg", lgbm_reg)],  weights=[7,12,16, 6])

pipe = Pipeline([
    ("col_tnf", col_tnf),
    ("vote", vote)
])

pipe.fit(X_train,y_train)
# Out:
# 0:	learn: 0.5968054	total: 3.34ms	remaining: 3.33s
# 1:	learn: 0.5757786	total: 7.92ms	remaining: 3.95s
# 2:	learn: 0.5553259	total: 12.8ms	remaining: 4.27s
# 3:	learn: 0.5364910	total: 17.6ms	remaining: 4.39s
# 4:	learn: 0.5179503	total: 22.3ms	remaining: 4.43s
# 5:	learn: 0.5019940	total: 25.3ms	remaining: 4.18s
# 6:	learn: 0.4857438	total: 28.2ms	remaining: 4s
# 7:	learn: 0.4706471	total: 33ms	remaining: 4.09s
# 8:	learn: 0.4575475	total: 37.7ms	remaining: 4.15s
# 9:	learn: 0.4449490	total: 39ms	remaining: 3.86s
# 10:	learn: 0.4315617	total: 43.6ms	remaining: 3.92s
# 11:	learn: 0.4194407	total: 45.7ms	remaining: 3.76s
# 12:	learn: 0.4080682	total: 50.4ms	remaining: 3.82s
# 13:	learn: 0.3977631	total: 55.2ms	remaining: 3.89s
# 14:	learn: 0.3881580	total: 59.7ms	remaining: 3.92s
# 15:	learn: 0.3790590	total: 64.2ms	remaining: 3.94s
# 16:	learn: 0.3690564	total: 68.3ms	remaining: 3.95s
# 17:	learn: 0.3594202	total: 72.4ms	remaining: 3.95s
# ...

# %%
y_pred = pipe.predict(X_test)

print('R2 score',np.round(r2_score(y_test,y_pred),5))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.88834
# MAE 0.1494829331617053

# %%
import pickle
import joblib

# %%
# joblib.dump(df, open("df.pkl", "wb"))
# joblib.dump(pipe, open("model.pkl", "wb"))

# %%
X_train.head(1)
# Out:
#     Company   TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 802    Dell  Ultrabook    8    1.29            0    0  165.632118
#
#          CPU Brand  HDD  SSD Gpu brand       OS
# 802  Intel Core i5    0  256     Intel  Windows

# %%
y_train[802]
# Out:
# 11.288114524334732

# %%
query = np.array(["Dell","Ultrabook",8,1.29,0,0,165.63,"Intel Core i5",0,256,"Intel", "Windows"], dtype=object)

# %%
query = query.reshape(1,12)

# %%
pipe.predict(query)
# Out:
# C:\Users\kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([11.24292255])

# %%
X_train
# Out:
#       Company     TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 802      Dell    Ultrabook    8    1.29            0    0  165.632118
# 1070     Dell     Notebook    4    2.06            0    0  100.454670
# 719        HP     Notebook    8    2.63            0    0  127.335675
# 1206       HP     Notebook    8    1.91            0    0  100.454670
# 45      Apple    Ultrabook    8    1.37            0    1  226.983005
# ...       ...          ...  ...     ...          ...  ...         ...
# 31       Asus     Notebook    2    1.65            0    0  111.935204
# 950        HP  Workstation    8    2.00            0    1  141.211998
# 1064      MSI       Gaming   16    1.80            0    0  141.211998
# 742   Toshiba     Notebook    8    1.25            1    1  157.350512
# 595    Lenovo     Notebook    8    2.29            0    0  100.454670
#
#           CPU Brand   HDD  SSD Gpu brand       OS
# 802   Intel Core i5     0  256     Intel  Windows
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1273
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int32
#  3   Weight       1273 non-null   float32
#  4   Price        1273 non-null   float64
#  5   Touchscreen  1273 non-null   int64
#  6   IPS          1273 non-null   int64
#  7   ppi          1273 non-null   float64
#  8   CPU Brand    1273 non-null   object
#  9   HDD          1273 non-null   int64
#  10  SSD          1273 non-null   int64
#  11  Gpu brand    1273 non-null   object
#  12  OS           1273 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 129.3+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1273
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int32
#  3   Weight       1273 non-null   float32
#  4   Price        1273 non-null   float64
#  5   Touchscreen  1273 non-null   int64
#  6   IPS          1273 non-null   int64
#  7   ppi          1273 non-null   float64
#  8   CPU Brand    1273 non-null   object
#  9   HDD          1273 non-null   int64
#  10  SSD          1273 non-null   int64
#  11  Gpu brand    1273 non-null   object
#  12  OS           1273 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 129.3+ KB
